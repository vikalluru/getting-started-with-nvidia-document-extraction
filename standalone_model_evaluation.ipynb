# %% [markdown]
# # Standalone Model Evaluation
#
# This notebook allows you to deploy and evaluate the individual NIM models (Nemotron Parse and NeMoRetriever OCR) **outside** of the full NV-Ingest pipeline. This is useful for:
# - Comparing model performance directly
# - Testing models before integrating with NV-Ingest
# - Debugging and development
#
# **Prerequisites**:
# 1. You need a NGC account and API Key (set in your `.env` file)
# 2. Docker must be installed and configured
#
# **Note**: If you deployed NV-Ingest with the respective profiles, these models may already be running. The cells below will check for existing deployments first.
#
# Checkout the build.nvidia.com endpoints to view the model results in a UI:
# - https://build.nvidia.com/nvidia/nemotron-parse
# - https://build.nvidia.com/nvidia/nemoretriever-ocr-v1

# %% [markdown]
# ## Nemotron Parse Standalone Evaluation
#
# [Nemotron Parse](https://build.nvidia.com/nvidia/nemotron-parse) is NVIDIA's state-of-the-art model for  document understanding. It extracts text, tables, and document structure in a single pass.
#
# **Model Details:**
# - Container: `nvcr.io/nvidia/nemo-microservices/nemotron-parse:latest`
# - Port: 8000 (standalone) or integrated via NV-Ingest
# - GPU Memory: ~8-16GB depending on document complexity

# %%
# %%bash
#
# # Check if Nemotron Parse is already running (either via NV-Ingest or standalone)
# echo "Checking for existing Nemotron Parse deployment..."
#
# if docker ps | grep -q "nemotron-parse"; then
#     echo "✓ Nemotron Parse is already running!"
#     docker ps | grep nemotron-parse
# else
#     echo "Nemotron Parse not found. Deploying standalone container..."
#     echo "This may take several minutes on first run..."
#
#     # Create cache directory
#     mkdir -p ~/.cache/nim
#
#     # Deploy Nemotron Parse standalone
#     export NGC_API_KEY=<your-api-key>
#     export LOCAL_NIM_CACHE=~/.cache/nim
#     mkdir -p "$LOCAL_NIM_CACHE"
#     docker run -d \
#         --name nemotron-parse-standalone \
#         --gpus all \
#         --shm-size=16GB \
#         -e NGC_API_KEY \
#         -v "$LOCAL_NIM_CACHE:/opt/nim/.cache" \
#         -u $(id -u) \
#         -p 8000:8000 \
#         nvcr.io/nim/nvidia/nemotron-parse:latest
#
#
#     echo "Nemotron Parse container started. Waiting for model to load..."
#     echo "Check status with: docker logs -f nemotron-parse-standalone"
# fi
# Out:
# Checking for existing Nemotron Parse deployment...
# Nemotron Parse not found. Deploying standalone container...
# This may take several minutes on first run...
# Unable to find image 'nvcr.io/nim/nvidia/nemotron-parse:latest' locally
# latest: Pulling from nim/nvidia/nemotron-parse
# d9d352c11bbd: Pulling fs layer
# 4f4fb700ef54: Pulling fs layer
# cebaad6571a9: Pulling fs layer
# 7848405aa76a: Pulling fs layer
# 3c313eb917ea: Pulling fs layer
# 1f7fdc9ac514: Pulling fs layer
# d1c1b0ca7e57: Pulling fs layer
# 9f11a52127b5: Pulling fs layer
# 1d7d94b9f382: Pulling fs layer
# f1af243d1e83: Pulling fs layer
# 3f893d6c8100: Pulling fs layer
# fa8ec00ab1d4: Pulling fs layer
# fa0fe06a747b: Pulling fs layer
# 77e2816d77cd: Pulling fs layer
# abb9b93d3c5f: Pulling fs layer
# 1b59656f075d: Pulling fs layer
# fb8084993d4d: Pulling fs layer
# 21a61217e20e: Pulling fs layer
# 8866bb33a5ff: Pulling fs layer
# 9f11a52127b5: Waiting
# 7dc054b813a9: Pulling fs layer
# 5c0a4f7c45dd: Pulling fs layer
# 1d7d94b9f382: Waiting
# f137fd4a4db3: Pulling fs layer
# e5992e1e6490: Pulling fs layer
# 2073c894355d: Pulling fs layer
# f191c297ebee: Pulling fs layer
# fa8ec00ab1d4: Waiting
# 6a8967222828: Pulling fs layer
# 15824fc38e92: Pulling fs layer
# d1eea2cf0300: Pulling fs layer
# 7848405aa76a: Waiting
# 3c313eb917ea: Waiting
# de528e3a95a4: Pulling fs layer
# f1af243d1e83: Waiting
# c4bdef8c1785: Pulling fs layer
# 3f893d6c8100: Waiting
# cfb435ec5406: Pulling fs layer
# 1f7fdc9ac514: Waiting
# 43b217ffe201: Pulling fs layer
# d1c1b0ca7e57: Waiting
# ec43be6b7071: Pulling fs layer
# abb9b93d3c5f: Waiting
# f137fd4a4db3: Waiting
# fa361d1935de: Pulling fs layer
# e5992e1e6490: Waiting
# 7e1a4c95bd00: Pulling fs layer
# 1b59656f075d: Waiting
# 77e2816d77cd: Waiting
# a43a2d8200ea: Pulling fs layer
# fb8084993d4d: Waiting
# 8866bb33a5ff: Waiting
# 406b1d3218ad: Pulling fs layer
# 5c88cd25aeb4: Pulling fs layer
# dfe39d65ed85: Pulling fs layer
# 15824fc38e92: Waiting
# d1eea2cf0300: Waiting
# 2ed25be7b50c: Pulling fs layer
# 2073c894355d: Waiting
# f191c297ebee: Waiting
# ea149f42037a: Pulling fs layer
# c4bdef8c1785: Waiting
# e8f0261de494: Pulling fs layer
# b662583d3e47: Pulling fs layer
# 43b217ffe201: Waiting
# 59628d59e8d4: Pulling fs layer
# 4c60bde74836: Pulling fs layer
# 23609ff39f0b: Pulling fs layer
# cccb7bbe17a0: Pulling fs layer
# 7dc054b813a9: Waiting
# 82ce8e601c06: Pulling fs layer
# 4225fbe5af83: Pulling fs layer
# 5c88cd25aeb4: Waiting
# fa361d1935de: Waiting
# 2ed25be7b50c: Waiting
# 864952d0b930: Pulling fs layer
# 7e1a4c95bd00: Waiting
# ea149f42037a: Waiting
# a300c1e6e35e: Pulling fs layer
# a43a2d8200ea: Waiting
# e8f0261de494: Waiting
# 23609ff39f0b: Waiting
# 655b40f09a8c: Pulling fs layer
# b662583d3e47: Waiting
# cccb7bbe17a0: Waiting
# 314699bddfd0: Pulling fs layer
# 406b1d3218ad: Waiting
# f736b001b31b: Pulling fs layer
# a300c1e6e35e: Waiting
# 56e758645b61: Pulling fs layer
# 59628d59e8d4: Waiting
# 5364de3372ba: Pulling fs layer
# 4c60bde74836: Waiting
# 864952d0b930: Waiting
# 4225fbe5af83: Waiting
# 655b40f09a8c: Waiting
# 2248d7024e77: Pulling fs layer
# 314699bddfd0: Waiting
# 56e758645b61: Waiting
# 855be2288259: Pulling fs layer
# 5364de3372ba: Waiting
# 11681b25c039: Pulling fs layer
# 82ce8e601c06: Waiting
# 1cede2c66d93: Pulling fs layer
# 855be2288259: Waiting
# 21a61217e20e: Waiting
# 11681b25c039: Waiting
# 2bf13d687de8: Pulling fs layer
# 1cede2c66d93: Waiting
# 840a2c156576: Pulling fs layer
# f736b001b31b: Waiting
# 2bf13d687de8: Waiting
# 840a2c156576: Waiting
# de528e3a95a4: Waiting
# dfe39d65ed85: Waiting
# 0a48fd7a832f: Pulling fs layer
# cfb435ec5406: Waiting
# fa0fe06a747b: Waiting
# ec43be6b7071: Waiting
# 4a9d8ac06557: Pulling fs layer
# d7bf60372bdd: Pulling fs layer
# d6b3358817b4: Pulling fs layer
# 4a9d8ac06557: Waiting
# d7bf60372bdd: Waiting
# d6b3358817b4: Waiting
# 3b15a8b586ae: Pulling fs layer
# 6a8967222828: Waiting
# d26f6f2ae96a: Pulling fs layer
# 3b15a8b586ae: Waiting
# 0a48fd7a832f: Waiting
# b0b43f1aa732: Pulling fs layer
# d26f6f2ae96a: Waiting
# 85428dad23cf: Pulling fs layer
# b0b43f1aa732: Waiting
# 85428dad23cf: Waiting
# 45fe516850c2: Pulling fs layer
# 5c0a4f7c45dd: Waiting
# 5825f342966c: Pulling fs layer
# d40b045ed7cd: Pulling fs layer
# 3344f50b74b1: Pulling fs layer
# 45fe516850c2: Waiting
# 00c6e3e2d1e1: Pulling fs layer
# 5825f342966c: Waiting
# 3344f50b74b1: Waiting
# d40b045ed7cd: Waiting
# 865d3fcc2814: Pulling fs layer
# 00c6e3e2d1e1: Waiting
# 17f8879c4db1: Pulling fs layer
# 865d3fcc2814: Waiting
# 17f8879c4db1: Waiting
# cebaad6571a9: Verifying Checksum
# cebaad6571a9: Download complete
# 4f4fb700ef54: Verifying Checksum
# 4f4fb700ef54: Download complete
# d9d352c11bbd: Verifying Checksum
# d9d352c11bbd: Download complete
# 1f7fdc9ac514: Download complete
# d9d352c11bbd: Pull complete
# 4f4fb700ef54: Pull complete
# 3c313eb917ea: Verifying Checksum
# 3c313eb917ea: Download complete
# 7848405aa76a: Verifying Checksum
# 7848405aa76a: Download complete
# cebaad6571a9: Pull complete
# d1c1b0ca7e57: Verifying Checksum
# d1c1b0ca7e57: Download complete
# 9f11a52127b5: Verifying Checksum
# 9f11a52127b5: Download complete
# 1d7d94b9f382: Verifying Checksum
# 1d7d94b9f382: Download complete
# 3f893d6c8100: Download complete
# fa8ec00ab1d4: Verifying Checksum
# fa8ec00ab1d4: Download complete
# 7848405aa76a: Pull complete
# 3c313eb917ea: Pull complete
# 1f7fdc9ac514: Pull complete
# d1c1b0ca7e57: Pull complete
# abb9b93d3c5f: Verifying Checksum
# abb9b93d3c5f: Download complete
# 9f11a52127b5: Pull complete
# 1d7d94b9f382: Pull complete
# f1af243d1e83: Pull complete
# 3f893d6c8100: Pull complete
# fa8ec00ab1d4: Pull complete
# 1b59656f075d: Verifying Checksum
# 1b59656f075d: Download complete
# fa0fe06a747b: Verifying Checksum
# fa0fe06a747b: Download complete
# 77e2816d77cd: Verifying Checksum
# 77e2816d77cd: Download complete
# fb8084993d4d: Verifying Checksum
# fb8084993d4d: Download complete
# 7dc054b813a9: Verifying Checksum
# 7dc054b813a9: Download complete
# 21a61217e20e: Verifying Checksum
# 21a61217e20e: Download complete
# 8866bb33a5ff: Verifying Checksum
# 8866bb33a5ff: Download complete
# e5992e1e6490: Verifying Checksum
# e5992e1e6490: Download complete
# f137fd4a4db3: Verifying Checksum
# f137fd4a4db3: Download complete
# fa0fe06a747b: Pull complete
# f191c297ebee: Verifying Checksum
# f191c297ebee: Download complete
# 5c0a4f7c45dd: Verifying Checksum
# 5c0a4f7c45dd: Download complete
# 2073c894355d: Verifying Checksum
# 2073c894355d: Download complete
# 6a8967222828: Verifying Checksum
# 6a8967222828: Download complete
# d1eea2cf0300: Verifying Checksum
# d1eea2cf0300: Download complete
# 15824fc38e92: Verifying Checksum
# 15824fc38e92: Download complete
# c4bdef8c1785: Verifying Checksum
# c4bdef8c1785: Download complete
# de528e3a95a4: Download complete
# cfb435ec5406: Verifying Checksum
# cfb435ec5406: Download complete
# 43b217ffe201: Verifying Checksum
# 43b217ffe201: Download complete
# fa361d1935de: Verifying Checksum
# fa361d1935de: Download complete
# ec43be6b7071: Verifying Checksum
# ec43be6b7071: Download complete
# 7e1a4c95bd00: Download complete
# 77e2816d77cd: Pull complete
# abb9b93d3c5f: Pull complete
# 1b59656f075d: Pull complete
# fb8084993d4d: Pull complete
# 406b1d3218ad: Verifying Checksum
# 406b1d3218ad: Download complete
# dfe39d65ed85: Verifying Checksum
# dfe39d65ed85: Download complete
# 2ed25be7b50c: Download complete
# ea149f42037a: Verifying Checksum
# ea149f42037a: Download complete
# e8f0261de494: Verifying Checksum
# e8f0261de494: Download complete
# 21a61217e20e: Pull complete
# b662583d3e47: Verifying Checksum
# b662583d3e47: Download complete
# 59628d59e8d4: Verifying Checksum
# 59628d59e8d4: Download complete
# 4c60bde74836: Download complete
# 23609ff39f0b: Verifying Checksum
# 23609ff39f0b: Download complete
# 8866bb33a5ff: Pull complete
# 7dc054b813a9: Pull complete
# cccb7bbe17a0: Verifying Checksum
# cccb7bbe17a0: Download complete
# 5c88cd25aeb4: Verifying Checksum
# 5c88cd25aeb4: Download complete
# 82ce8e601c06: Download complete
# 4225fbe5af83: Verifying Checksum
# 4225fbe5af83: Download complete
# 864952d0b930: Verifying Checksum
# 864952d0b930: Download complete
# a300c1e6e35e: Download complete
# 314699bddfd0: Download complete
# 655b40f09a8c: Download complete
# f736b001b31b: Verifying Checksum
# f736b001b31b: Download complete
# 5c0a4f7c45dd: Pull complete
# f137fd4a4db3: Pull complete
# e5992e1e6490: Pull complete
# 2248d7024e77: Verifying Checksum
# 2248d7024e77: Download complete
# 5364de3372ba: Verifying Checksum
# 5364de3372ba: Download complete
# 2073c894355d: Pull complete
# f191c297ebee: Pull complete
# 6a8967222828: Pull complete
# 15824fc38e92: Pull complete
# d1eea2cf0300: Pull complete
# de528e3a95a4: Pull complete
# c4bdef8c1785: Pull complete
# cfb435ec5406: Pull complete
# 855be2288259: Verifying Checksum
# 855be2288259: Download complete
# 11681b25c039: Verifying Checksum
# 11681b25c039: Download complete
# 43b217ffe201: Pull complete
# 1cede2c66d93: Download complete
# 2bf13d687de8: Download complete
# ec43be6b7071: Pull complete
# fa361d1935de: Pull complete
# 0a48fd7a832f: Download complete
# 840a2c156576: Verifying Checksum
# 840a2c156576: Download complete
# 4a9d8ac06557: Verifying Checksum
# 4a9d8ac06557: Download complete
# d7bf60372bdd: Download complete
# d6b3358817b4: Verifying Checksum
# d6b3358817b4: Download complete
# 3b15a8b586ae: Verifying Checksum
# d26f6f2ae96a: Verifying Checksum
# d26f6f2ae96a: Download complete
# b0b43f1aa732: Verifying Checksum
# b0b43f1aa732: Download complete
# 85428dad23cf: Download complete
# 45fe516850c2: Download complete
# 5825f342966c: Verifying Checksum
# 5825f342966c: Download complete
# d40b045ed7cd: Verifying Checksum
# d40b045ed7cd: Download complete
# 7e1a4c95bd00: Pull complete
# 3344f50b74b1: Verifying Checksum
# 3344f50b74b1: Download complete
# 00c6e3e2d1e1: Verifying Checksum
# 00c6e3e2d1e1: Download complete
# 865d3fcc2814: Verifying Checksum
# 865d3fcc2814: Download complete
# 17f8879c4db1: Verifying Checksum
# 17f8879c4db1: Download complete
# a43a2d8200ea: Verifying Checksum
# a43a2d8200ea: Download complete
# a43a2d8200ea: Pull complete
# 406b1d3218ad: Pull complete
# 5c88cd25aeb4: Pull complete
# dfe39d65ed85: Pull complete
# 2ed25be7b50c: Pull complete
# ea149f42037a: Pull complete
# e8f0261de494: Pull complete
# b662583d3e47: Pull complete
# 59628d59e8d4: Pull complete
# 4c60bde74836: Pull complete
# 23609ff39f0b: Pull complete
# cccb7bbe17a0: Pull complete
# 82ce8e601c06: Pull complete
# 4225fbe5af83: Pull complete
# 864952d0b930: Pull complete
# a300c1e6e35e: Pull complete
# 655b40f09a8c: Pull complete
# 314699bddfd0: Pull complete
# f736b001b31b: Pull complete
# 56e758645b61: Pull complete
# 5364de3372ba: Pull complete
# 2248d7024e77: Pull complete
# 855be2288259: Pull complete
# 11681b25c039: Pull complete
# 1cede2c66d93: Pull complete
# 2bf13d687de8: Pull complete
# 840a2c156576: Pull complete
# 0a48fd7a832f: Pull complete
# 4a9d8ac06557: Pull complete
# d7bf60372bdd: Pull complete
# d6b3358817b4: Pull complete
# 3b15a8b586ae: Pull complete
# d26f6f2ae96a: Pull complete
# b0b43f1aa732: Pull complete
# 85428dad23cf: Pull complete
# 45fe516850c2: Pull complete
# 5825f342966c: Pull complete
# d40b045ed7cd: Pull complete
# 3344f50b74b1: Pull complete
# 00c6e3e2d1e1: Pull complete
# 865d3fcc2814: Pull complete
# 17f8879c4db1: Pull complete
# Digest: sha256:626a5620b48c5c1a45b67b6ebf5e00b3284bbd59b396a2a2248a4babc0bab6fb
# Status: Downloaded newer image for nvcr.io/nim/nvidia/nemotron-parse:latest
# 0152151ec9e685ac24170a57ea00098c2e7289ad3b90ca00fc4bbfb67bc1387f
# Nemotron Parse container started. Waiting for model to load...
# Check status with: docker logs -f nemotron-parse-standalone

# %% [markdown]
# ### Test Nemotron Parse
#
# Once the model is loaded, you can test it with a sample document. The model accepts base64-encoded images or PDF pages.

# %%
import requests
import base64
import json
from pathlib import Path

# Sample image URL for testing
SAMPLE_IMAGE_URL = "https://assets.ngc.nvidia.com/products/api-catalog/nemotron-parse/example_2.jpg"

def test_nemotron_parse(
    image_source: str, 
    endpoint: str = "http://localhost:8000/v1/chat/completions",
    tool_type: str = "markdown_bbox"
):
    """
    Test Nemotron Parse with a document image.
    
    Based on: https://docs.nvidia.com/nim/vision-language-models/latest/examples/nemotron-parse/api.html
    
    Args:
        image_source: Either a URL (http/https) or a local file path (PNG, JPG)
        endpoint: The Nemotron Parse API endpoint
        tool_type: Extraction mode - one of:
            - "markdown_bbox": (default) Text with bounding boxes in markdown format
            - "markdown_no_bbox": Text in markdown format without bounding boxes
            - "detection_only": Bounding boxes and types only, no text transcription
    
    Returns:
        List of detected elements with text, bounding boxes, and types
    """
    # Determine if input is a URL or local file
    if image_source.startswith(("http://", "https://")):
        # Use URL directly - the API will download it
        image_url = image_source
    else:
        # Read local file and encode as base64
        with open(image_source, "rb") as f:
            image_data = base64.b64encode(f.read()).decode("utf-8")
        
        # Determine media type from file extension
        suffix = Path(image_source).suffix.lower()
        media_types = {".png": "image/png", ".jpg": "image/jpeg", ".jpeg": "image/jpeg"}
        media_type = media_types.get(suffix, "image/png")
        image_url = f"data:{media_type};base64,{image_data}"
    
    # Prepare the request payload per official API docs
    # Note: Text input is not supported - only images
    payload = {
        "model": "nvidia/nemotron-parse",
        "tools": [
            {
                "type": "function",
                "function": {
                    "name": tool_type  # markdown_bbox, markdown_no_bbox, or detection_only
                }
            }
        ],
        "messages": [
            {
                "role": "user",
                "content": [
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": image_url
                        }
                    }
                ]
            }
        ],
        "temperature": 0.0
    }
    
    try:
        response = requests.post(endpoint, json=payload, timeout=120)
        response.raise_for_status()
        result = response.json()
        
        # Parse the tool call response
        tool_call = result["choices"][0]["message"]["tool_calls"][0]
        detections = json.loads(tool_call["function"]["arguments"])
        return detections
        
    except requests.exceptions.ConnectionError:
        return {"error": "Could not connect to Nemotron Parse. Make sure the container is running and model is loaded."}
    except KeyError as e:
        return {"error": f"Unexpected response format: {e}", "raw_response": result}
    except Exception as e:
        return {"error": str(e)}

# Check if service is ready
print("Checking Nemotron Parse health...")
try:
    health = requests.get("http://localhost:8000/v1/health/ready", timeout=10)
    if health.status_code == 200:
        print("✓ Nemotron Parse is ready!")
        print("\nTest with the sample image:")
        print(f'  result = test_nemotron_parse("{SAMPLE_IMAGE_URL}")')
        print("\nOr use a local file:")
        print('  result = test_nemotron_parse("./path/to/image.png")')
        print('\nTool types available:')
        print('  - "markdown_bbox" (default): Text + bounding boxes')
        print('  - "markdown_no_bbox": Text only, no bounding boxes')
        print('  - "detection_only": Bounding boxes only, no text')
    else:
        print(f"Service returned status: {health.status_code}")
except requests.exceptions.ConnectionError:
    print("⏳ Nemotron Parse is still loading. Please wait and try again.")
    print("   Check status with: !docker logs -f nemotron-parse-standalone")
# Out:
# Checking Nemotron Parse health...
# ✓ Nemotron Parse is ready!
#
# Test with the sample image:
#   result = test_nemotron_parse("https://assets.ngc.nvidia.com/products/api-catalog/nemotron-parse/example_2.jpg")
#
# Or use a local file:
#   result = test_nemotron_parse("./path/to/image.png")
#
# Tool types available:
#   - "markdown_bbox" (default): Text + bounding boxes
#   - "markdown_no_bbox": Text only, no bounding boxes
#   - "detection_only": Bounding boxes only, no text

# %%
 result = test_nemotron_parse("https://assets.ngc.nvidia.com/products/api-catalog/nemotron-parse/example_2.jpg")

# %%
result
# Out:
# [[{'bbox': {'xmin': 0.0565878453038674,
#     'ymin': 0.0648,
#     'xmax': 0.9412497237569062,
#     'ymax': 0.0781},
#    'text': '_Appl. Sci._ **2023**, _13_, 12967 4 of 21',
#    'type': 'Page-header'},
#   {'bbox': {'xmin': 0.2754486187845304,
#     'ymin': 0.3078,
#     'xmax': 0.9412497237569062,
#     'ymax': 0.5164},
#    'text': 'The adopted experimental equipment for performing VHCF tests was an ultrasonic fatigue testing machine (UFTM). The UFTM is shown in Figure 1 and was developed at Politecnico di Torino for testing components in the chosen fatigue range. The UFTM can perform tests at \\(20\\pm 0.5\\) kHz under fully reversed tension-compression stress (_R_=-1), which significantly reduces the testing time compared to conventional testing apparatuses. To perform fatigue tests, the UFTM adopts the following devices: (i) an electric generator (Branson DCX 4 kW, not visible in Figure 1) which generates an electrical sinusoidal wave at 20 kHz; (ii) a piezoelectric transducer, responsible for converting the electrical wave into a mechanical vibration; (iii) a booster and a horn made of Ti-6Al-4V that amplify and convey the vibration to the specimen under testing; (iv) the specimen under investigation, which was designed for the UFTM resonance conditions; (v) a laser displacement sensor that measures the displacement at the specimen free end; (vi) vortex tubes to keep the temperature controlled in the range (20-24) \\(^\\circ\\)C; and (vii) a temperature sensor to observe the temperature evolution during the test execution.',
#    'type': 'Text'},
#   {'bbox': {'xmin': 0.2765867403314917,
#     'ymin': 0.85,
#     'xmax': 0.9412497237569062,
#     'ymax': 0.9313},
#    'text': 'Performing fatigue tests with the UFTM consists of the application of alternated stress in specimens that are designed to work in resonance conditions. The specimen and the vibration components are thus designed to have a resonance frequency corresponding to a longitudinal mode of vibration close to 20 kHz. Moreover, the UFTM adopts a closed-loop proportional-integrative-derivative (PID) control logic where the displacement measured',
#    'type': 'Text'},
#   {'bbox': {'xmin': 0.058750276243093924,
#     'ymin': 0.1375,
#     'xmax': 0.9389734806629835,
#     'ymax': 0.2883},
#    'text': '\\begin{tabular}{cccccc}\n\\multirow{2}{*}{**Quantity**} & \\multirow{2}{*}{**Symbol**} & \\multirow{2}{*}{**Units**} & \\multicolumn{3}{c}{**Materials**} \\\\ & & & **Ti-6Al-4V** & **Al. 7075 T6** & **SikaPower®-1277** \\\\ Modulus of elasticity & E & MPa & 115,000 & 71,955 ± 224 & 2280 ± 533 \\\\ Poisson’s ratio & _v_ & / & 0.34 & 0.3 & 0.33 \\\\ Ultimate tensile strength & _σuts_ & MPa & 950 & 610 ± 15 & 35.7 ± 1.4 \\\\ Density & _ρ_ & g/cc & 4.395 & 2.8 & 1.1 \\\\ Loss factor & LF & / & 2.96 × 10-4 & 3.5 × 10-3 & 2 × 10-2 \\\\ Viscosity & V & Pa·s & / & / & 430 (at 20 °C) \\\\ \\end{tabular}',
#    'type': 'Table'},
#   {'bbox': {'xmin': 0.1543524861878453,
#     'ymin': 0.5312,
#     'xmax': 0.8500861878453039,
#     'ymax': 0.818},
#    'text': 'Piezoelectric transducer Vortex tube Booster Horn Temperature sensor Specimen Laser-displacement sensor',
#    'type': 'Picture'},
#   {'bbox': {'xmin': 0.2754486187845304,
#     'ymin': 0.1133,
#     'xmax': 0.5322088397790055,
#     'ymax': 0.1273},
#    'text': '** 1.** Adopted material properties.',
#    'type': 'Caption'},
#   {'bbox': {'xmin': 0.2765867403314917,
#     'ymin': 0.8313,
#     'xmax': 0.526632044198895,
#     'ymax': 0.8453},
#    'text': '**Figure 1.** The UFTM equipment [43].',
#    'type': 'Caption'}]]

# %% [markdown]
# ### Cleanup Nemotron Parse Standalone
#
# Run this cell to stop and remove the standalone Nemotron Parse container when you're done testing.

# %%
# %%bash
#
# # Stop and remove the standalone Nemotron Parse container
# if docker ps -a | grep -q "nemotron-parse-standalone"; then
#     echo "Stopping Nemotron Parse standalone container..."
#     docker stop nemotron-parse-standalone
#     docker rm nemotron-parse-standalone
#     echo "✓ Nemotron Parse standalone container removed."
# else
#     echo "No standalone Nemotron Parse container found."
# fi
# Out:
# Stopping Nemotron Parse standalone container...
# nemotron-parse-standalone
# nemotron-parse-standalone
# ✓ Nemotron Parse standalone container removed.

# %% [markdown]
# ## NeMoRetriever OCR Standalone Evaluation
#
# [NeMoRetriever OCR](https://build.nvidia.com/nvidia/nemoretriever-ocr-v1/deploy) is NVIDIA's high-performance OCR model that provides faster and more accurate text extraction compared to PaddleOCR.
#
# **Model Details:**
# - Container: `nvcr.io/nvidia/nemo-microservices/nemoretriever-ocr-v1:latest`
# - Port: 8001 (standalone to avoid conflict with Nemotron Parse)
# - Model Name: `scene_text_ensemble`
# - GPU Memory: ~4-8GB

# %%
# %%bash
#
# # Check if NeMoRetriever OCR is already running (either via NV-Ingest or standalone)
# echo "Checking for existing NeMoRetriever OCR deployment..."
#
# if docker ps | grep -q "nemoretriever-ocr"; then
#     echo "✓ NeMoRetriever OCR is already running!"
#     docker ps | grep nemoretriever-ocr
# else
#     echo "NeMoRetriever OCR not found. Deploying standalone container..."
#     echo "This may take several minutes on first run..."
#
#     # Create cache directory
#     mkdir -p ~/.cache/nim
#
#     # Deploy NeMoRetriever OCR standalone on port 8001
#     # Deploy Nemotron Parse standalone
#     export NGC_API_KEY=<your-api-key>
#     export LOCAL_NIM_CACHE=~/.cache/nim
#     mkdir -p "$LOCAL_NIM_CACHE"
#     docker run -d \
#         --name nemotron-ocr-standalone \
#         --gpus all \
#         --shm-size=16GB \
#         -e NGC_API_KEY \
#         -v "$LOCAL_NIM_CACHE:/opt/nim/.cache" \
#         -u $(id -u) \
#         -p 8000:8000 \
#         nvcr.io/nim/nvidia/nemoretriever-ocr-v1:latest
#
#     echo "NeMoRetriever OCR container started. Waiting for model to load..."
#     echo "Check status with: docker logs -f nemoretriever-ocr-standalone"
# fi
# Out:
# Checking for existing NeMoRetriever OCR deployment...
# NeMoRetriever OCR not found. Deploying standalone container...
# This may take several minutes on first run...
# Unable to find image 'nvcr.io/nim/nvidia/nemoretriever-ocr-v1:latest' locally
# latest: Pulling from nim/nvidia/nemoretriever-ocr-v1
# 76249c7cd503: Pulling fs layer
# 4f4fb700ef54: Pulling fs layer
# 2c012c05aa52: Pulling fs layer
# e208c1addcef: Pulling fs layer
# fd1d0313cdb1: Pulling fs layer
# 25b35e68ee46: Pulling fs layer
# a5196ab7827e: Pulling fs layer
# 1029073a30ca: Pulling fs layer
# e208c1addcef: Waiting
# fd1d0313cdb1: Waiting
# 9a1ae0b54ca0: Pulling fs layer
# 25b35e68ee46: Waiting
# b2653b5a2bd4: Pulling fs layer
# a5196ab7827e: Waiting
# 9a1ae0b54ca0: Waiting
# 1029073a30ca: Waiting
# 0480cd94b346: Pulling fs layer
# b2653b5a2bd4: Waiting
# 812e57e14e40: Pulling fs layer
# 2cc679c17d7f: Pulling fs layer
# 0480cd94b346: Waiting
# 812e57e14e40: Waiting
# 92fff3630921: Pulling fs layer
# 2cc679c17d7f: Waiting
# 92fff3630921: Waiting
# 16216e2fe824: Pulling fs layer
# cef11905364f: Pulling fs layer
# 16216e2fe824: Waiting
# 5b3fe16cb4d1: Pulling fs layer
# ba3f119ad6b1: Pulling fs layer
# cef11905364f: Waiting
# 5b3fe16cb4d1: Waiting
# 823635e152d9: Pulling fs layer
# febf8f69281d: Pulling fs layer
# ba3f119ad6b1: Waiting
# 823635e152d9: Waiting
# 2975bac17c40: Pulling fs layer
# 857daef51b9b: Pulling fs layer
# febf8f69281d: Waiting
# 2975bac17c40: Waiting
# fa24537c4bad: Pulling fs layer
# 4d6c50f00c32: Pulling fs layer
# 857daef51b9b: Waiting
# fa24537c4bad: Waiting
# 17d8b71405e7: Pulling fs layer
# 4d6c50f00c32: Waiting
# d2f153cf1e46: Pulling fs layer
# 31cc42185474: Pulling fs layer
# 1fead7796e96: Pulling fs layer
# 17d8b71405e7: Waiting
# d2f153cf1e46: Waiting
# f6da5a69ddee: Pulling fs layer
# 6771877e4d65: Pulling fs layer
# 31cc42185474: Waiting
# f6da5a69ddee: Waiting
# 1fead7796e96: Waiting
# 3a5716408829: Pulling fs layer
# 7a5367cb0c79: Pulling fs layer
# daaa3ed47512: Pulling fs layer
# 6771877e4d65: Waiting
# 3a5716408829: Waiting
# 7a5367cb0c79: Waiting
# c0649d66189a: Pulling fs layer
# 9f8281484354: Pulling fs layer
# 0b2bd7ee7be1: Pulling fs layer
# daaa3ed47512: Waiting
# c0649d66189a: Waiting
# 5b8d747ac30c: Pulling fs layer
# 9f8281484354: Waiting
# 0b2bd7ee7be1: Waiting
# 27fdbb46abc5: Pulling fs layer
# 5b8d747ac30c: Waiting
# afad298904cb: Pulling fs layer
# 52451b22f0c2: Pulling fs layer
# 27fdbb46abc5: Waiting
# afad298904cb: Waiting
# 52451b22f0c2: Waiting
# 4f4fb700ef54: Download complete
# 2c012c05aa52: Verifying Checksum
# 2c012c05aa52: Download complete
# 76249c7cd503: Verifying Checksum
# 76249c7cd503: Download complete
# e208c1addcef: Verifying Checksum
# e208c1addcef: Download complete
# fd1d0313cdb1: Verifying Checksum
# fd1d0313cdb1: Download complete
# 76249c7cd503: Pull complete
# 4f4fb700ef54: Pull complete
# a5196ab7827e: Verifying Checksum
# a5196ab7827e: Download complete
# 25b35e68ee46: Verifying Checksum
# 25b35e68ee46: Download complete
# 1029073a30ca: Download complete
# 9a1ae0b54ca0: Verifying Checksum
# 9a1ae0b54ca0: Download complete
# b2653b5a2bd4: Verifying Checksum
# b2653b5a2bd4: Download complete
# 812e57e14e40: Verifying Checksum
# 812e57e14e40: Download complete
# 0480cd94b346: Download complete
# 2cc679c17d7f: Download complete
# 2c012c05aa52: Pull complete
# 92fff3630921: Verifying Checksum
# 92fff3630921: Download complete
# e208c1addcef: Pull complete
# fd1d0313cdb1: Pull complete
# cef11905364f: Verifying Checksum
# cef11905364f: Download complete
# 16216e2fe824: Verifying Checksum
# 16216e2fe824: Download complete
# 5b3fe16cb4d1: Verifying Checksum
# 5b3fe16cb4d1: Download complete
# ba3f119ad6b1: Download complete
# 25b35e68ee46: Pull complete
# 823635e152d9: Verifying Checksum
# 823635e152d9: Download complete
# a5196ab7827e: Pull complete
# 1029073a30ca: Pull complete
# 9a1ae0b54ca0: Pull complete
# febf8f69281d: Verifying Checksum
# febf8f69281d: Download complete
# 857daef51b9b: Verifying Checksum
# 857daef51b9b: Download complete
# b2653b5a2bd4: Pull complete
# 0480cd94b346: Pull complete
# 812e57e14e40: Pull complete
# 2cc679c17d7f: Pull complete
# fa24537c4bad: Verifying Checksum
# fa24537c4bad: Download complete
# 92fff3630921: Pull complete
# 4d6c50f00c32: Verifying Checksum
# 4d6c50f00c32: Download complete
# 17d8b71405e7: Download complete
# 31cc42185474: Verifying Checksum
# 31cc42185474: Download complete
# d2f153cf1e46: Verifying Checksum
# d2f153cf1e46: Download complete
# 2975bac17c40: Verifying Checksum
# 2975bac17c40: Download complete
# 1fead7796e96: Verifying Checksum
# 1fead7796e96: Download complete
# 16216e2fe824: Pull complete
# f6da5a69ddee: Verifying Checksum
# f6da5a69ddee: Download complete
# 6771877e4d65: Verifying Checksum
# 6771877e4d65: Download complete
# 3a5716408829: Verifying Checksum
# 3a5716408829: Download complete
# daaa3ed47512: Verifying Checksum
# daaa3ed47512: Download complete
# c0649d66189a: Verifying Checksum
# c0649d66189a: Download complete
# cef11905364f: Pull complete
# 9f8281484354: Verifying Checksum
# 9f8281484354: Download complete
# 0b2bd7ee7be1: Verifying Checksum
# 0b2bd7ee7be1: Download complete
# 5b8d747ac30c: Verifying Checksum
# 5b8d747ac30c: Download complete
# 27fdbb46abc5: Verifying Checksum
# 27fdbb46abc5: Download complete
# afad298904cb: Verifying Checksum
# afad298904cb: Download complete
# 52451b22f0c2: Verifying Checksum
# 52451b22f0c2: Download complete
# 5b3fe16cb4d1: Pull complete
# ba3f119ad6b1: Pull complete
# 823635e152d9: Pull complete
# febf8f69281d: Pull complete
# 2975bac17c40: Pull complete
# 857daef51b9b: Pull complete
# fa24537c4bad: Pull complete
# 4d6c50f00c32: Pull complete
# 17d8b71405e7: Pull complete
# d2f153cf1e46: Pull complete
# 31cc42185474: Pull complete
# 1fead7796e96: Pull complete
# f6da5a69ddee: Pull complete
# 6771877e4d65: Pull complete
# 3a5716408829: Pull complete
# 7a5367cb0c79: Verifying Checksum
# 7a5367cb0c79: Download complete
# 7a5367cb0c79: Pull complete
# daaa3ed47512: Pull complete
# c0649d66189a: Pull complete
# 9f8281484354: Pull complete
# 0b2bd7ee7be1: Pull complete
# 5b8d747ac30c: Pull complete
# 27fdbb46abc5: Pull complete
# afad298904cb: Pull complete
# 52451b22f0c2: Pull complete
# Digest: sha256:a374c8a63d347eb345af843461fdbcb86054c3ba4a0de7ce7171aaff6f2467b9
# Status: Downloaded newer image for nvcr.io/nim/nvidia/nemoretriever-ocr-v1:latest
# 1ecf924e797ef9f5f443f4314674a048c7ec41b9d6f0073b0aee8a63d002718c
# NeMoRetriever OCR container started. Waiting for model to load...
# Check status with: docker logs -f nemoretriever-ocr-standalone

# %% [markdown]
# ### Test NeMoRetriever OCR
#
# Once the model is loaded, you can test it with a sample image. The model accepts base64-encoded images and returns extracted text with bounding boxes.

# %%
import requests
import base64
from pathlib import Path

# Sample image URL for testing OCR
SAMPLE_OCR_IMAGE_URL = "https://assets.ngc.nvidia.com/products/api-catalog/nemotron-parse/example_2.jpg"

def test_nemoretriever_ocr(
    image_source: str, 
    endpoint: str = "http://localhost:8000/v1/infer"
):
    """
    Test NeMoRetriever OCR with an image.
    
    Based on: https://build.nvidia.com/nvidia/nemoretriever-ocr-v1/deploy
    
    Args:
        image_source: Either a URL (http/https) or a local file path (PNG, JPG)
        endpoint: The NeMoRetriever OCR API endpoint
    
    Returns:
        OCR results with extracted text and bounding boxes
    """
    # For URLs, download first then encode
    if image_source.startswith(("http://", "https://")):
        # Download image from URL
        img_response = requests.get(image_source, timeout=30)
        img_response.raise_for_status()
        image_data = base64.b64encode(img_response.content).decode("utf-8")
    else:
        # Read local file and encode as base64
        with open(image_source, "rb") as f:
            image_data = base64.b64encode(f.read()).decode("utf-8")
    
    # NeMoRetriever OCR expects objects with 'type' and 'url' fields
    # URL must be a data URL with base64 encoded image
    payload = {
        "input": [
            {
                "type": "image_url",
                "url": f"data:image/jpeg;base64,{image_data}"
            }
        ]
    }
    
    headers = {
        "accept": "application/json",
        "Content-Type": "application/json"
    }
    
    try:
        response = requests.post(endpoint, headers=headers, json=payload, timeout=120)
        response.raise_for_status()
        result = response.json()
        return result
    except requests.exceptions.HTTPError as e:
        # Get detailed error from response
        try:
            error_detail = response.json()
        except:
            error_detail = response.text
        return {"error": str(e), "detail": error_detail}
    except requests.exceptions.ConnectionError:
        return {"error": "Could not connect to NeMoRetriever OCR. Make sure the container is running and model is loaded."}
    except Exception as e:
        return {"error": str(e)}

# Check if service is ready
print("Checking NeMoRetriever OCR health...")
try:
    health = requests.get("http://localhost:8000/v1/health/ready", timeout=10)
    if health.status_code == 200:
        print("✓ NeMoRetriever OCR is ready!")
        print("\nTest with the sample image:")
        print(f'  result = test_nemoretriever_ocr("{SAMPLE_OCR_IMAGE_URL}")')
        print("\nOr use a local file:")
        print('  result = test_nemoretriever_ocr("./path/to/image.png")')
    else:
        print(f"Service returned status: {health.status_code}")
except requests.exceptions.ConnectionError:
    print("⏳ NeMoRetriever OCR is still loading. Please wait and try again.")
    print("   Check status with: !docker logs -f nemotron-ocr-standalone")
# Out:
# Checking NeMoRetriever OCR health...
# ✓ NeMoRetriever OCR is ready!
#
# Test with the sample image:
#   result = test_nemoretriever_ocr("https://assets.ngc.nvidia.com/products/api-catalog/nemotron-parse/example_2.jpg")
#
# Or use a local file:
#   result = test_nemoretriever_ocr("./path/to/image.png")

# %%
result = test_nemoretriever_ocr("https://assets.ngc.nvidia.com/products/api-catalog/nemotron-parse/example_2.jpg")

# %%
result
# Out:
# {'data': [{'index': 0,
#    'text_detections': [{'text_prediction': {'text': 'Appl. Sci. 2023, 13, 12967',
#       'confidence': 0.9621646701868591},
#      'bounding_box': {'points': [{'x': 0.05840383097529411,
#         'y': 0.06721106916666031},
#        {'x': 0.20411844551563263, 'y': 0.06721106916666031},
#        {'x': 0.20411844551563263, 'y': 0.07830017060041428},
#        {'x': 0.05840383097529411, 'y': 0.07830017060041428}]}},
#     {'text_prediction': {'text': 'oof 21', 'confidence': 0.5725537641363276},
#      'bounding_box': {'points': [{'x': 0.9043284058570862,
#         'y': 0.06817606836557388},
#        {'x': 0.9392924308776855, 'y': 0.06817606836557388},
#        {'x': 0.9392924308776855, 'y': 0.07534684240818024},
#        {'x': 0.9043284058570862, 'y': 0.07534684240818024}]}},
#     {'text_prediction': {'text': 'Table 1. Adopted material properties.',
#       'confidence': 0.9481045938087516},
#      'bounding_box': {'points': [{'x': 0.2790148854255676,
#         'y': 0.11504768580198288},
#        {'x': 0.5299150943756104, 'y': 0.11504768580198288},
#        {'x': 0.5299150943756104, 'y': 0.1270442008972168},
#        {'x': 0.2790148854255676, 'y': 0.1270442008972168}]}},
#     {'text_prediction': {'text': 'Materials',
#       'confidence': 0.9986280162011292},
#      'bounding_box': {'points': [{'x': 0.711209774017334,
#         'y': 0.14288870990276337},
#        {'x': 0.7757359147071838, 'y': 0.14288870990276337},
#        {'x': 0.7757359147071838, 'y': 0.15099795162677765},
#        {'x': 0.711209774017334, 'y': 0.15099795162677765}]}},
#     {'text_prediction': {'text': 'Quantity', 'confidence': 0.9489726543300241},
#      'bounding_box': {'points': [{'x': 0.1512807309627533,
#         'y': 0.15245969593524933},
#        {'x': 0.21359223127365112, 'y': 0.15245969593524933},
#        {'x': 0.21359223127365112, 'y': 0.1645408272743225},
#        {'x': 0.1512807309627533, 'y': 0.1645408272743225}]}},
#     {'text_prediction': {'text': 'Symbol', 'confidence': 0.9764477098490756},
#      'bounding_box': {'points': [{'x': 0.3365073800086975,
#         'y': 0.1520790457725525},
#        {'x': 0.3904727101325989, 'y': 0.1520790457725525},
#        {'x': 0.3904727101325989, 'y': 0.16410517692565918},
#        {'x': 0.3365073800086975, 'y': 0.16410517692565918}]}},
#     {'text_prediction': {'text': 'Units', 'confidence': 0.8837623513262531},
#      'bounding_box': {'points': [{'x': 0.46758970618247986,
#         'y': 0.15421542525291443},
#        {'x': 0.5056211948394775, 'y': 0.15421542525291443},
#        {'x': 0.5056211948394775, 'y': 0.1631077527999878},
#        {'x': 0.46758970618247986, 'y': 0.1631077527999878}]}},
#     {'text_prediction': {'text': 'Ti-6AI-4V',
#       'confidence': 0.7870528781057109},
#      'bounding_box': {'points': [{'x': 0.5741425156593323,
#         'y': 0.16158030927181244},
#        {'x': 0.6432639956474304, 'y': 0.16158030927181244},
#        {'x': 0.6432639956474304, 'y': 0.17027024924755096},
#        {'x': 0.5741425156593323, 'y': 0.17027024924755096}]}},
#     {'text_prediction': {'text': 'Al. 7075 T6',
#       'confidence': 0.8792130187228749},
#      'bounding_box': {'points': [{'x': 0.6932984590530396,
#         'y': 0.16191475093364716},
#        {'x': 0.7693765759468079, 'y': 0.16191475093364716},
#        {'x': 0.7693765759468079, 'y': 0.17012208700180054},
#        {'x': 0.6932984590530396, 'y': 0.17012208700180054}]}},
#     {'text_prediction': {'text': 'SikaFowerē-1277',
#       'confidence': 0.5208692830912995},
#      'bounding_box': {'points': [{'x': 0.8055467009544373,
#         'y': 0.16116750240325928},
#        {'x': 0.9249588847160339, 'y': 0.16116750240325928},
#        {'x': 0.9249588847160339, 'y': 0.17116574943065643},
#        {'x': 0.8055467009544373, 'y': 0.17116574943065643}]}},
#     {'text_prediction': {'text': 'Modulus of elasticity',
#       'confidence': 0.9704200572808697},
#      'bounding_box': {'points': [{'x': 0.11123023182153702,
#         'y': 0.17951937019824982},
#        {'x': 0.2526770234107971, 'y': 0.17951937019824982},
#        {'x': 0.2526770234107971, 'y': 0.19134852290153503},
#        {'x': 0.11123023182153702, 'y': 0.19134852290153503}]}},
#     {'text_prediction': {'text': 'E', 'confidence': 0.8507723618296265},
#      'bounding_box': {'points': [{'x': 0.3590567111968994,
#         'y': 0.18038702011108398},
#        {'x': 0.3693576157093048, 'y': 0.18038702011108398},
#        {'x': 0.3693576157093048, 'y': 0.1885020136833191},
#        {'x': 0.3590567111968994, 'y': 0.1885020136833191}]}},
#     {'text_prediction': {'text': 'MPa', 'confidence': 0.9480572905375771},
#      'bounding_box': {'points': [{'x': 0.47036439180374146,
#         'y': 0.18003246188163757},
#        {'x': 0.501433789730072, 'y': 0.18003246188163757},
#        {'x': 0.501433789730072, 'y': 0.18855315446853638},
#        {'x': 0.47036439180374146, 'y': 0.18855315446853638}]}},
#     {'text_prediction': {'text': '115,000', 'confidence': 0.9910782407541684},
#      'bounding_box': {'points': [{'x': 0.5835059285163879,
#         'y': 0.1796652227640152},
#        {'x': 0.6325980424880981, 'y': 0.1796652227640152},
#        {'x': 0.6325980424880981, 'y': 0.18951648473739624},
#        {'x': 0.5835059285163879, 'y': 0.18951648473739624}]}},
#     {'text_prediction': {'text': '71,955 à 224',
#       'confidence': 0.7348228027006326},
#      'bounding_box': {'points': [{'x': 0.6884024739265442,
#         'y': 0.17955133318901062},
#        {'x': 0.7733132243156433, 'y': 0.17955133318901062},
#        {'x': 0.7733132243156433, 'y': 0.18943430483341217},
#        {'x': 0.6884024739265442, 'y': 0.18943430483341217}]}},
#     {'text_prediction': {'text': '2280 ع 533',
#       'confidence': 0.8648530415377257},
#      'bounding_box': {'points': [{'x': 0.8282005190849304,
#         'y': 0.17989040911197662},
#        {'x': 0.9013505578041077, 'y': 0.17989040911197662},
#        {'x': 0.9013505578041077, 'y': 0.1884423792362213},
#        {'x': 0.8282005190849304, 'y': 0.1884423792362213}]}},
#     {'text_prediction': {'text': "Poisson's ratio",
#       'confidence': 0.9875023667701683},
#      'bounding_box': {'points': [{'x': 0.134480819106102,
#         'y': 0.19861173629760742},
#        {'x': 0.2296402007341385, 'y': 0.19861173629760742},
#        {'x': 0.2296402007341385, 'y': 0.2071237862110138},
#        {'x': 0.134480819106102, 'y': 0.2071237862110138}]}},
#     {'text_prediction': {'text': '0.34', 'confidence': 0.9093017648263843},
#      'bounding_box': {'points': [{'x': 0.5952187776565552,
#         'y': 0.19891268014907837},
#        {'x': 0.6222706437110901, 'y': 0.19891268014907837},
#        {'x': 0.6222706437110901, 'y': 0.20736153423786163},
#        {'x': 0.5952187776565552, 'y': 0.20736153423786163}]}},
#     {'text_prediction': {'text': '0.3', 'confidence': 0.9851033960363867},
#      'bounding_box': {'points': [{'x': 0.72151780128479,
#         'y': 0.19926902651786804},
#        {'x': 0.7403932213783264, 'y': 0.19926902651786804},
#        {'x': 0.7403932213783264, 'y': 0.2073890119791031},
#        {'x': 0.72151780128479, 'y': 0.2073890119791031}]}},
#     {'text_prediction': {'text': '0.33', 'confidence': 0.9486515896877048},
#      'bounding_box': {'points': [{'x': 0.8518127202987671,
#         'y': 0.1991562396287918},
#        {'x': 0.8787187337875366, 'y': 0.1991562396287918},
#        {'x': 0.8787187337875366, 'y': 0.20734310150146484},
#        {'x': 0.8518127202987671, 'y': 0.20734310150146484}]}},
#     {'text_prediction': {'text': 'Ultimate tensile strength',
#       'confidence': 0.9842788596867925},
#      'bounding_box': {'points': [{'x': 0.1001977026462555,
#         'y': 0.21752551198005676},
#        {'x': 0.262908399105072, 'y': 0.21752551198005676},
#        {'x': 0.262908399105072, 'y': 0.22821670770645142},
#        {'x': 0.1001977026462555, 'y': 0.22821670770645142}]}},
#     {'text_prediction': {'text': 'MPa', 'confidence': 0.9457215969179906},
#      'bounding_box': {'points': [{'x': 0.47032633423805237,
#         'y': 0.21736477315425873},
#        {'x': 0.50096195936203, 'y': 0.21736477315425873},
#        {'x': 0.50096195936203, 'y': 0.22589904069900513},
#        {'x': 0.47032633423805237, 'y': 0.22589904069900513}]}},
#     {'text_prediction': {'text': '950', 'confidence': 0.9951646530249696},
#      'bounding_box': {'points': [{'x': 0.5969429016113281,
#         'y': 0.21741580963134766},
#        {'x': 0.6198025941848755, 'y': 0.21741580963134766},
#        {'x': 0.6198025941848755, 'y': 0.2263919860124588},
#        {'x': 0.5969429016113281, 'y': 0.2263919860124588}]}},
#     {'text_prediction': {'text': '610 : 15', 'confidence': 0.7583703715474988},
#      'bounding_box': {'points': [{'x': 0.7015721797943115,
#         'y': 0.21751843392848969},
#        {'x': 0.7603424787521362, 'y': 0.21751843392848969},
#        {'x': 0.7603424787521362, 'y': 0.2260131686925888},
#        {'x': 0.7015721797943115, 'y': 0.2260131686925888}]}},
#     {'text_prediction': {'text': '35.7 1.4', 'confidence': 0.9593517035627599},
#      'bounding_box': {'points': [{'x': 0.8318511843681335,
#         'y': 0.21726946532726288},
#        {'x': 0.8984187245368958, 'y': 0.21726946532726288},
#        {'x': 0.8984187245368958, 'y': 0.2259942889213562},
#        {'x': 0.8318511843681335, 'y': 0.2259942889213562}]}},
#     {'text_prediction': {'text': 'Density', 'confidence': 0.9949000997521743},
#      'bounding_box': {'points': [{'x': 0.15585055947303772,
#         'y': 0.23632082343101501},
#        {'x': 0.20759662985801697, 'y': 0.23632082343101501},
#        {'x': 0.20759662985801697, 'y': 0.24688413739204407},
#        {'x': 0.15585055947303772, 'y': 0.24688413739204407}]}},
#     {'text_prediction': {'text': 'p', 'confidence': 0.658596464934213},
#      'bounding_box': {'points': [{'x': 0.35901355743408203,
#         'y': 0.23888760805130005},
#        {'x': 0.3681541085243225, 'y': 0.23888760805130005},
#        {'x': 0.3681541085243225, 'y': 0.24725651741027832},
#        {'x': 0.35901355743408203, 'y': 0.24725651741027832}]}},
#     {'text_prediction': {'text': 'g/cc', 'confidence': 0.9428279195819605},
#      'bounding_box': {'points': [{'x': 0.4717305302619934,
#         'y': 0.23598217964172363},
#        {'x': 0.5021403431892395, 'y': 0.23598217964172363},
#        {'x': 0.5021403431892395, 'y': 0.24709758162498474},
#        {'x': 0.4717305302619934, 'y': 0.24709758162498474}]}},
#     {'text_prediction': {'text': '4.395', 'confidence': 0.971709622315617},
#      'bounding_box': {'points': [{'x': 0.592958390712738,
#         'y': 0.23635299503803253},
#        {'x': 0.6259853839874268, 'y': 0.23635299503803253},
#        {'x': 0.6259853839874268, 'y': 0.24560627341270447},
#        {'x': 0.592958390712738, 'y': 0.24560627341270447}]}},
#     {'text_prediction': {'text': '2.8', 'confidence': 0.882916303127932},
#      'bounding_box': {'points': [{'x': 0.7209537625312805,
#         'y': 0.2367575764656067},
#        {'x': 0.7404903769493103, 'y': 0.2367575764656067},
#        {'x': 0.7404903769493103, 'y': 0.2452262043952942},
#        {'x': 0.7209537625312805, 'y': 0.2452262043952942}]}},
#     {'text_prediction': {'text': '1.1', 'confidence': 0.9147465606179807},
#      'bounding_box': {'points': [{'x': 0.8555121421813965,
#         'y': 0.23654043674468994},
#        {'x': 0.8735526204109192, 'y': 0.23654043674468994},
#        {'x': 0.8735526204109192, 'y': 0.24536322057247162},
#        {'x': 0.8555121421813965, 'y': 0.24536322057247162}]}},
#     {'text_prediction': {'text': 'Loss factor',
#       'confidence': 0.9923212742243673},
#      'bounding_box': {'points': [{'x': 0.14637711644172668,
#         'y': 0.2551534175872803},
#        {'x': 0.2178969830274582, 'y': 0.2551534175872803},
#        {'x': 0.2178969830274582, 'y': 0.26342034339904785},
#        {'x': 0.14637711644172668, 'y': 0.26342034339904785}]}},
#     {'text_prediction': {'text': 'L.F', 'confidence': 0.5396323775015466},
#      'bounding_box': {'points': [{'x': 0.35519644618034363,
#         'y': 0.2548973858356476},
#        {'x': 0.3731382489204407, 'y': 0.2548973858356476},
#        {'x': 0.3731382489204407, 'y': 0.2631048858165741},
#        {'x': 0.35519644618034363, 'y': 0.2631048858165741}]}},
#     {'text_prediction': {'text': '2.96 x 10-4',
#       'confidence': 0.9386917484421677},
#      'bounding_box': {'points': [{'x': 0.5670573115348816,
#         'y': 0.2553572654724121},
#        {'x': 0.6477673649787903, 'y': 0.2553572654724121},
#        {'x': 0.6477673649787903, 'y': 0.2638484537601471},
#        {'x': 0.5670573115348816, 'y': 0.2638484537601471}]}},
#     {'text_prediction': {'text': '3.5 x 10-3',
#       'confidence': 0.9614206032430443},
#      'bounding_box': {'points': [{'x': 0.6937307715415955,
#         'y': 0.25513240694999695},
#        {'x': 0.7672911882400513, 'y': 0.25513240694999695},
#        {'x': 0.7672911882400513, 'y': 0.2637387216091156},
#        {'x': 0.6937307715415955, 'y': 0.2637387216091156}]}},
#     {'text_prediction': {'text': '2 x 10-2', 'confidence': 0.8799055656917671},
#      'bounding_box': {'points': [{'x': 0.8329926133155823,
#         'y': 0.25513437390327454},
#        {'x': 0.8954881429672241, 'y': 0.25513437390327454},
#        {'x': 0.8954881429672241, 'y': 0.26383212208747864},
#        {'x': 0.8329926133155823, 'y': 0.26383212208747864}]}},
#     {'text_prediction': {'text': 'Viscosity',
#       'confidence': 0.9494473887519796},
#      'bounding_box': {'points': [{'x': 0.15242800116539001,
#         'y': 0.2732886075973511},
#        {'x': 0.21116922795772552, 'y': 0.2732886075973511},
#        {'x': 0.21116922795772552, 'y': 0.28444620966911316},
#        {'x': 0.15242800116539001, 'y': 0.28444620966911316}]}},
#     {'text_prediction': {'text': 'V', 'confidence': 0.8054989603448967},
#      'bounding_box': {'points': [{'x': 0.3583061993122101,
#         'y': 0.2732369303703308},
#        {'x': 0.3701683580875397, 'y': 0.2732369303703308},
#        {'x': 0.3701683580875397, 'y': 0.2818749248981476},
#        {'x': 0.3583061993122101, 'y': 0.2818749248981476}]}},
#     {'text_prediction': {'text': 'Pa-5', 'confidence': 0.6855416369728576},
#      'bounding_box': {'points': [{'x': 0.4726160764694214,
#         'y': 0.2743038535118103},
#        {'x': 0.49988681077957153, 'y': 0.2743038535118103},
#        {'x': 0.49988681077957153, 'y': 0.2823126018047333},
#        {'x': 0.4726160764694214, 'y': 0.2823126018047333}]}},
#     {'text_prediction': {'text': '430 (at 20 "C)',
#       'confidence': 0.8716295384360901},
#      'bounding_box': {'points': [{'x': 0.8207932710647583,
#         'y': 0.2730981111526489},
#        {'x': 0.9098376035690308, 'y': 0.2730981111526489},
#        {'x': 0.9098376035690308, 'y': 0.2840314209461212},
#        {'x': 0.8207932710647583, 'y': 0.2840314209461212}]}},
#     {'text_prediction': {'text': 'The adopted experimental equipment for performing VHCF tests was an ultrasonic fatigue testing machine (UFTM). The UFTM is shown in Figure and was developed at Politecnico di Torino for testing components in the chosen fatigue range. The UFTM can perform tests at 20 : 0.5 kHz under fully reversed tension-compression stress (R ===17 -1), which significantly reduces the testing time compared to conventional testing apparatuses. To perform fatigue tests, the UFTM adopts the following devices: (i) an electric generator (Branson DCX kW, not visible in Figure 1) which generates an electrical sinusoidal wave at 20 kHz; (ii) piezoelectric transducer, responsible for converting the electrical wave into mechanical vibration; (iii) booster and a horn made of Ti-6Al-4V that amplify and convey the vibration to the specimen under testing; (iv) the specimen under investigation, which was designed for the UFTM resonance conditions; (v) a laser displacement sensor that measures the displacement at the specimen free end; (vi) vortex tubes to keep the temperature controlled in the range (20-24) "C; and (vii) a temperature sensor to observe the temperature evolution during the test execution.',
#       'confidence': 0.9517572571457426},
#      'bounding_box': {'points': [{'x': 0.27859795093536377,
#         'y': 0.30999791622161865},
#        {'x': 0.9419863224029541, 'y': 0.30999791622161865},
#        {'x': 0.9419863224029541, 'y': 0.517024576663971},
#        {'x': 0.27859795093536377, 'y': 0.517024576663971}]}},
#     {'text_prediction': {'text': 'Piezoelectric transducer',
#       'confidence': 0.8867955589136172},
#      'bounding_box': {'points': [{'x': 0.7193308472633362,
#         'y': 0.5585256218910217},
#        {'x': 0.8082050085067749, 'y': 0.5585256218910217},
#        {'x': 0.8082050085067749, 'y': 0.5828470587730408},
#        {'x': 0.7193308472633362, 'y': 0.5828470587730408}]}},
#     {'text_prediction': {'text': 'Booster', 'confidence': 0.9537268893405998},
#      'bounding_box': {'points': [{'x': 0.7128647565841675,
#         'y': 0.6369753479957581},
#        {'x': 0.766562283039093, 'y': 0.6369753479957581},
#        {'x': 0.766562283039093, 'y': 0.6457935571670532},
#        {'x': 0.7128647565841675, 'y': 0.6457935571670532}]}},
#     {'text_prediction': {'text': 'Vortex tube',
#       'confidence': 0.9873391268610372},
#      'bounding_box': {'points': [{'x': 0.19445687532424927,
#         'y': 0.6439260840415955},
#        {'x': 0.27207714319229126, 'y': 0.6439260840415955},
#        {'x': 0.27207714319229126, 'y': 0.652877151966095},
#        {'x': 0.19445687532424927, 'y': 0.652877151966095}]}},
#     {'text_prediction': {'text': 'Horn', 'confidence': 0.8739801906420253},
#      'bounding_box': {'points': [{'x': 0.7102001905441284,
#         'y': 0.6626638770103455},
#        {'x': 0.7444441914558411, 'y': 0.6626638770103455},
#        {'x': 0.7444441914558411, 'y': 0.6717678308486938},
#        {'x': 0.7102001905441284, 'y': 0.6717678308486938}]}},
#     {'text_prediction': {'text': 'Temperature sensor',
#       'confidence': 0.9891851430303422},
#      'bounding_box': {'points': [{'x': 0.15857532620429993,
#         'y': 0.6843138933181763},
#        {'x': 0.28943997621536255, 'y': 0.6843138933181763},
#        {'x': 0.28943997621536255, 'y': 0.6961771249771118},
#        {'x': 0.15857532620429993, 'y': 0.6961771249771118}]}},
#     {'text_prediction': {'text': 'Specimen', 'confidence': 0.9335007574795616},
#      'bounding_box': {'points': [{'x': 0.7022703886032104,
#         'y': 0.6938648223876953},
#        {'x': 0.7688871026039124, 'y': 0.6938648223876953},
#        {'x': 0.7688871026039124, 'y': 0.706403374671936},
#        {'x': 0.7022703886032104, 'y': 0.706403374671936}]}},
#     {'text_prediction': {'text': 'Laser-displacement',
#       'confidence': 0.969707166473827},
#      'bounding_box': {'points': [{'x': 0.7114803194999695,
#         'y': 0.7212879061698914},
#        {'x': 0.840229332447052, 'y': 0.7212879061698914},
#        {'x': 0.840229332447052, 'y': 0.7331394553184509},
#        {'x': 0.7114803194999695, 'y': 0.7331394553184509}]}},
#     {'text_prediction': {'text': 'sensor', 'confidence': 0.9251449477372029},
#      'bounding_box': {'points': [{'x': 0.7109037637710571,
#         'y': 0.7377467155456543},
#        {'x': 0.7544278502464294, 'y': 0.7377467155456543},
#        {'x': 0.7544278502464294, 'y': 0.7451955080032349},
#        {'x': 0.7109037637710571, 'y': 0.7451955080032349}]}},
#     {'text_prediction': {'text': 'Figure 1.',
#       'confidence': 0.9623870048593782},
#      'bounding_box': {'points': [{'x': 0.2794886827468872,
#         'y': 0.8335017561912537},
#        {'x': 0.3384440839290619, 'y': 0.8335017561912537},
#        {'x': 0.3384440839290619, 'y': 0.8447133302688599},
#        {'x': 0.2794886827468872, 'y': 0.8447133302688599}]}},
#     {'text_prediction': {'text': 'The UFTM equipment [43].',
#       'confidence': 0.963579109336882},
#      'bounding_box': {'points': [{'x': 0.34235653281211853,
#         'y': 0.8333548903465271},
#        {'x': 0.5249897241592407, 'y': 0.8333548903465271},
#        {'x': 0.5249897241592407, 'y': 0.8453353047370911},
#        {'x': 0.34235653281211853, 'y': 0.8453353047370911}]}},
#     {'text_prediction': {'text': 'Performing fatigue tests with the UFTM consists of the application of alternated stress in specimens that are designed to work in resonance conditions. The specimen and the vibration components are thus designed to have resonance frequency corresponding to longitudinal mode of vibration close to 20 kHz. Moreover, the UFTM adopts closed-loop aropotinnd--nggaattee-ee-evvvi (PID) control logic where the displacement measured',
#       'confidence': 0.949514815696233},
#      'bounding_box': {'points': [{'x': 0.2783079147338867,
#         'y': 0.8579967021942139},
#        {'x': 0.9398488402366638, 'y': 0.8579967021942139},
#        {'x': 0.9398488402366638, 'y': 0.9320067763328552},
#        {'x': 0.2783079147338867, 'y': 0.9320067763328552}]}}]}],
#  'usage': {'images_size_mb': 0.5878934860229492}}

# %% [markdown]
# ### Cleanup NeMoRetriever OCR Standalone
#
# Run this cell to stop and remove the standalone NeMoRetriever OCR container when you're done testing.

# %%
# %%bash
#
# # Stop and remove the standalone NeMoRetriever OCR container
# if docker ps -a | grep -q "nemotron-ocr-standalone"; then
#     echo "Stopping NeMoRetriever OCR standalone container..."
#     docker stop nemotron-parse-standalone
#     docker rm nemotron-parse-standalone
#     echo "✓ NeMoRetriever OCR standalone container removed."
# else
#     echo "No standalone NeMoRetriever OCR container found."
# fi
# Out:
# No standalone NeMoRetriever OCR container found.
